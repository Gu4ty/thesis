# %%
import sys
sys.path.append("../")

# %%
INTERVAL_LOW = 0
INTERVAL_HIGH = 100

# %%
import random
a = 0.2
b = 0.1
N = 50
normalization_factor = N
def system(y, t,a,b):
    S, I, R = y
    dSdt = -a * S * I / N
    dIdt = a * S * I / N - b * I
    dRdt = b * I
    return dSdt, dIdt, dRdt



def get_time_norm_function(function, max_time):
    def function_norm_time(t):
        return function(t * max_time)

    return function_norm_time

include_time = False

class ExactModel:
    def eval_model(self, X):
        
#         if include_time:
#             return [-0.2 * (X[1] * normalization_factor) * X[2] * normalization_factor / N]
#         else:
#             return [-0.2 * (X[0] * normalization_factor) * X[1] * normalization_factor / N]

#         if include_time:
#             return [a * X[1] * normalization_factor * X[2]* normalization_factor / N - b * X[3]*normalization_factor]
#         else:
#             return [a * X[0] * normalization_factor * X[1]* normalization_factor / N - b * X[2]*normalization_factor]

        if include_time:
            return [b* X[2]*normalization_factor]
        else:
            return [b* X[1]*normalization_factor]


def initial_conditions_sir(population_size, number_of_initial_conditions):
    def generate_initial_conditions(sum_of_numbers = 1000):
        l = [random.randint(0, sum_of_numbers) for i in range(2)]
        l+= [0, sum_of_numbers]
        l.sort()
        sir = []
        for i in range(1, len(l)):
            sir.append(l[i] - l[i-1])
        return sir
#     def generate_initial_conditions(sum_of_numbers = 1000):
#         return [random.randint(0,sum_of_numbers) for _ in range(3)]
    yield [population_size-1,1,0]
    for i in range(number_of_initial_conditions -1):  
        yield generate_initial_conditions(population_size)

        
exact = ExactModel()

# %%
from interpolation.interpolate_system import odeint_interpolate
from interpolation.regression_dataset import RegressionDataset

import matplotlib.pyplot as plt
import numpy as np

number_of_systems = 100
samples_per_system = 1000

dataset_train = None
dataset_test = None

population_size = N

print("Generating training data...")
f, axes = plt.subplots(3, 1, sharex='col', sharey='col', figsize=(7, 15))
for init_conditions in initial_conditions_sir(population_size, number_of_systems):
    assert sum(init_conditions) == N, f"sum is {sum(init_conditions)}, must be {N}"
    y_inter = odeint_interpolate( system, init_conditions, INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b))
    y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]
    t = np.linspace(INTERVAL_LOW, INTERVAL_HIGH, 10000)
    S,I,R = y_inter
    axes[0].plot(t, [S(ti) for ti in t])
    axes[1].plot(t, [I(ti) for ti in t])
    axes[2].plot(t, [R(ti) for ti in t])
    
#     y_inter_time_norm = y_inter_time_norm[:2]
    print(init_conditions)
    def y_prime(t):
#         return -a * y_inter_time_norm[0](t) * y_inter_time_norm[1](t) / N
#         return a * y_inter_time_norm[0](t) * y_inter_time_norm[1](t) /N - b * y_inter_time_norm[2](t)
        return b * y_inter_time_norm[1](t)
    
    d_train = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 80 // 100, include_time,0,0.2)
    d_test = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 20 // 100, include_time,0,0.2)
   
    if dataset_train:
        dataset_train.concat_dataset(d_train)
        dataset_test.concat_dataset(d_test)
    else:
        dataset_train = d_train
        dataset_test = d_test

print("Done")
axes[0].set_title("S(t)")
axes[1].set_title("I(t)")
axes[2].set_title("R(t)")
  
plt.legend()
plt.show()
# Out:
# Generating training data...
# [49, 1, 0]
# [3, 38, 9]
# [12, 34, 4]
# [31, 14, 5]
# [3, 40, 7]
# [21, 9, 20]
# [5, 35, 10]
# [10, 13, 27]
# [5, 25, 20]
# [1, 40, 9]
# [33, 14, 3]
# [7, 20, 23]
# [6, 21, 23]
# [9, 6, 35]
# [40, 8, 2]
# [6, 26, 18]
# [2, 33, 15]
# [40, 7, 3]
# [32, 5, 13]
# [10, 37, 3]
# [2, 10, 38]
# [21, 7, 22]
# [1, 37, 12]
# [41, 5, 4]
# [29, 1, 20]
# [22, 23, 5]
# [25, 14, 11]
# [16, 26, 8]
# [29, 13, 8]
# [20, 26, 4]
# [41, 5, 4]
# [21, 6, 23]
# [1, 3, 46]
# [24, 6, 20]
# [0, 8, 42]
# [40, 2, 8]
# [17, 4, 29]
# [29, 18, 3]
# [17, 24, 9]
# [16, 1, 33]
# [7, 25, 18]
# [45, 1, 4]
# [22, 21, 7]
# [8, 14, 28]
# [2, 27, 21]
# [33, 1, 16]
# [17, 20, 13]
# [7, 21, 22]
# [30, 9, 11]
# [14, 5, 31]
# [17, 18, 15]
# [22, 15, 13]
# [17, 25, 8]
# [34, 15, 1]
# [28, 15, 7]
# [11, 18, 21]
# [22, 12, 16]
# [38, 9, 3]
# [12, 13, 25]
# [15, 22, 13]
# [9, 22, 19]
# [1, 7, 42]
# [33, 7, 10]
# [13, 20, 17]
# [31, 0, 19]
# [17, 23, 10]
# [33, 16, 1]
# [4, 15, 31]
# [26, 12, 12]
# [12, 17, 21]
# [33, 0, 17]
# [22, 12, 16]
# [22, 9, 19]
# [9, 17, 24]
# [16, 27, 7]
# [25, 10, 15]
# [48, 1, 1]
# [18, 13, 19]
# [6, 20, 24]
# [15, 6, 29]
# [24, 25, 1]
# [17, 27, 6]
# [9, 5, 36]
# [7, 3, 40]
# [0, 50, 0]
# [21, 17, 12]
# [2, 25, 23]
# [13, 0, 37]
# [1, 13, 36]
# [17, 2, 31]
# [12, 33, 5]
# [8, 22, 20]
# [10, 10, 30]
# [6, 44, 0]
# [7, 5, 38]
# [13, 11, 26]
# [49, 0, 1]
# [11, 11, 28]
# [15, 24, 11]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [5, 19, 26]
# Done

# %%
len(dataset_train.X)
# Out:
# 800000

# %%
# %load_ext autoreload
# %autoreload 2
from interpolation.regression_nn import RegressionNN
m1 = RegressionNN.nn_dataset_regression(dataset_train, dataset_test)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# NVIDIA GeForce RTX 3050 Ti Laptop GPU
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.3 GB
# epoch: 0
# Avg loss: 0.47832749093867594
# epoch: 10
# Avg loss: 6.525666080287366e-05
# epoch: 20
# Avg loss: 0.0004091676946225098
# epoch: 30
# Avg loss: 5.8140774090718136e-05
# epoch: 40
# Avg loss: 1.8494707935066762e-05
# epoch: 50
# Avg loss: 0.00030579063724845703
# epoch: 60
# Avg loss: 0.00023772522497471997
# epoch: 70
# Avg loss: 0.00010402490415362601
# epoch: 80
# Avg loss: 5.8274663446329034e-05
# epoch: 90
# Avg loss: 9.885145854012417e-06
# Avg loss: 1.6391187320939033e-05

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon
from query_set.regression_dependency import check_linear_dependency
import matplotlib.pyplot as plt


# y_inter = odeint_interpolate( system, [N-1, 1, 0], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b) )
y_inter = odeint_interpolate( system, [25, 20, 5], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]
# y_inter_time_norm = y_inter_time_norm[:2]


f, axes = plt.subplots(5, 6, figsize=(30, 20))



for i in range(5):
    for j in range(6):
        dependency_graph_epsilon(
            m1,
            1,
            y_inter_time_norm,
            0,
            0.2,
            normalization_factor,
            25,
            1000,
            include_time,
            "",
            "b",
            "",
            "",
            exact,
            axes[i,j]
        )


f.supxlabel(r'$\hat{S}$')
f.supylabel(r'$h(\hat{S})$')
f.suptitle(r'Diferentes valores de $h(\hat{S})$ para distintos $t_0$', fontsize=14)
plt.savefig('sir_N_50_X_tsir.png', bbox_inches='tight')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.1405083524264184 [array(9.79990234), array(11.78751254), array(28.41258511)]
# 0.15107913568181233 [array(9.33821308), array(11.0427642), array(29.61902272)]
# 0.05940683847480832 [array(15.84184496), array(17.75263083), array(16.40552421)]
# 0.11158495821401189 [array(11.37068312), array(13.93338068), array(24.6959362)]
# 0.08016327827426523 [array(13.75154464), array(16.30533845), array(19.94311691)]
# 0.05631638747268786 [array(16.19533761), array(17.95085198), array(15.85381041)]
# 0.11580274290631021 [array(11.10950563), array(13.61362622), array(25.27686814)]
# 0.02270797158241693 [array(20.87176331), array(19.61627063), array(9.51196606)]
# 0.14054584339935364 [array(9.79817037), array(11.78482577), array(28.41700386)]
# 0.11096040450498475 [array(11.41039945), array(13.98083397), array(24.60876658)]
# 0.035937377442691924 [array(18.83858091), array(19.08719696), array(12.07422213)]
# 0.08950036956732839 [array(12.9558163), array(15.61090841), array(21.43327528)]
# 0.19042731141484923 [array(8.00951633), array(8.53434766), array(33.45613602)]
# 0.12335108996949365 [array(10.67127924), array(13.04572379), array(26.28299698)]
# 0.02406495964820206 [array(20.65095828), array(19.57118855), array(9.77785317)]
# 0.15386607922507778 [array(9.22495019), array(10.85094897), array(29.92410084)]
# 0.052989084953484755 [array(16.58921867), array(18.15771118), array(15.25307015)]
# 0.1283932161386425 [array(10.39810542), array(12.67058936), array(26.93130523)]
# 0.08744486719355218 [array(13.12401282), array(15.76518115), array(21.11080603)]
# 0.04819022403984914 [array(17.18236931), array(18.4428306), array(14.37480008)]
# 0.014661847250497396 [array(22.24031307), array(19.83545469), array(7.92423224)]
# 0.09783305549421312 [array(12.31184176), array(14.98030086), array(22.70785738)]
# 0.1138137890827687 [array(11.23115652), array(13.76424136), array(25.00460213)]
# 0.07477726554606086 [array(14.24922138), array(16.6964395), array(19.05433912)]
# 0.0421623081046634 [array(17.97101608), array(18.77609436), array(13.25288956)]
# 0.08804790316411762 [array(13.074271), array(15.71998949), array(21.20573951)]
# 0.05140827631313887 [array(16.7812956), array(18.25343174), array(14.96527267)]
# 0.16522446694286444 [array(8.79649127), array(10.09043625), array(31.11307249)]
# 0.05606683827397479 [array(16.22439597), array(17.9666095), array(15.80899453)]
# 0.0038660226138957257 [array(24.23877812), array(19.98817007), array(5.7730518)]

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad_dataset

values = check_var_exist_grad_dataset(m1, 0, dataset_train)
avr = sum(values)/len(values)
print(avr)


values = check_var_exist_grad_dataset(m1, 1, dataset_train)
avr = sum(values)/len(values)
print(avr)


values = check_var_exist_grad_dataset(m1, 2, dataset_train)
avr = sum(values)/len(values)
print(avr)

values = check_var_exist_grad_dataset(m1, 3, dataset_train)
avr = sum(values)/len(values)
print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1.3733816991269547
# 3.5956643735563047
# 1.3737105858883165
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [62], in <cell line: 19>()
#      16 avr = sum(values)/len(values)
#      17 print(avr)
# ---> 19 values = check_var_exist_grad_dataset(m1, 3, dataset_train)
#      20 avr = sum(values)/len(values)
#      21 print(avr)
#
# File /mnt/8CD8D439D8D422EE/Escuela/Tesis/Tesis/src/tests/../query_set/check_var_exist.py:102, in check_var_exist_grad_dataset(m, var_idx, dataset)
#     100 number_of_elements = min(100000, len(dataset.X))
#     101 for x in dataset.X[:number_of_elements]:
# --> 102     v = m.m_grad(var_idx, np.array(x.cpu()))  # dN/d_idx(X)
#     103     values.append(abs(v))
#     105 return values
#
# File /mnt/8CD8D439D8D422EE/Escuela/Tesis/Tesis/src/tests/../interpolation/regression_nn.py:237, in RegressionNN.m_grad(self, i, x)
#     235 y.backward(retain_graph=True)
#     236 g = r.grad  # dy/dp0(x) dy/dp1(x) dy/dp2(x)....dy/dpn(x)
# --> 237 return g[i].cpu().detach().numpy()
#
# IndexError: index 3 is out of bounds for dimension 0 with size 3

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_polynomial_dependency

result = check_polynomial_dependency(
        m1,
        2,
        y_inter_time_norm,
        0,
        1,
        3,
        normalization_factor,
        25,
        1000,
        include_time)

print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'polynomial': [-8.09946994259115e-07, 2.5621667530983395e-05, -0.02742725118459148, 1.2565807777147195], 'determination': 0.9999998646926636}

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon_mean

dependency_graph_epsilon_mean(m1,
                              0,
                              dataset_train, 
                              normalization_factor, 
                              20, 
                              1000, 
                              "N(X_idx)", 
                              "b", "X_idx", 
                              "N(X_idx)",
                              exact)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad

y_inter = odeint_interpolate( system, [N-1, 1, 0], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]

values = check_var_exist_grad(m1,3, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.018949269915813437

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad_dataset, check_var_exist_grad_dataset_epsilon

# values = check_var_exist_grad_dataset(m1, 0, dataset_train)
# avr = sum(values)/len(values)
# print(avr)

values = check_var_exist_grad_dataset_epsilon(m1, 0, dataset_train, normalization_factor, epsilon = 10)
avr = sum(values)/len(values)
print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_102143/1826766395.py", line 9, in <cell line: 9>
#     values = check_var_exist_grad_dataset_epsilon(m1, 0, dataset_train, normalization_factor, epsilon = 10)
#   File "/mnt/8CD8D439D8D422EE/Escuela/Tesis/Tesis/src/tests/../query_set/check_var_exist.py", line 119, in check_var_exist_grad_dataset_epsilon
#     var_idx_values = np.linspace(lower_bound, upper_bound, 1000)
#   File "<__array_function__ internals>", line 180, in linspace
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/numpy/core/function_base.py", line 128, in linspace
#     stop  = asanyarray(stop)  * 1.0
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/torch/_tensor.py", line 757, in __array__
#     return self.numpy()
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/dgd/miniconda3/envs/thesis116/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X, y = load_iris(return_X_y=True)
print(X.shape)
X_new = SelectKBest(chi2, k=2).fit_transform(X, y)
X_new.shape
# Out:
# (150, 4)
# (150, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

a,b,c,d = 1,1,1,50

x = np.linspace(1,50,2)
y = np.linspace(1,50,2)

X,Y = np.meshgrid(x,y)
Z = (d - a*X - b*Y) / c

print(X)
print(-------------------------------------------------------)
print(Y)
print(-------------------------------------------------------)
print(Z)
print(-------------------------------------------------------)

# X1 = []
# Y1 =[]
# Z1 = []
# for i in range(len(Z)):
#       if Z[i] > 0:
#             X1.append(X[i])
#             Y1.append(Y[i])
#             Z1.append(Z[i])

# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')


# surf = ax.plot_surface(X1, Y1, Z1)
# Out:
# [[ 1. 50.]
#  [ 1. 50.]]
# [[ 1.  1.]
#  [50. 50.]]
# [[ 48.  -1.]
#  [ -1. -50.]]
