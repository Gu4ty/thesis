# %%
import sys
sys.path.append("../")

# %%
import random

INTERVAL_LOW = 0
INTERVAL_HIGH = 100
SAMPLES = int(1e5)

a = 0.04
b = 0.0005
c = 0.2
d = 0.004
normalization_factor = 100

def system(y, t,a,b,c,d):
    X, Y = y   
    dXdt =  X*(a - b*Y) 
    dYdt = -Y*(c - d*X)
    return dXdt, dYdt

def get_time_norm_function(function, max_time):
    def function_norm_time(t):
        return function(t * max_time)

    return function_norm_time


def initial_conditions_lotka(population_size, number_of_initial_conditions):
    def generate_initial_conditions(population_size):
        N = population_size
        x = random.randint(1,N -1)
        y = N - x
        return  [x,y]
    
    yield [population_size//2,population_size//2]
    for i in range(number_of_initial_conditions -1):  
        yield generate_initial_conditions(population_size)

include_time = False
# The ideal trained neural network model
class ExactModel:
    def eval_model(self, X):
#         if include_time:
#             return [X[1]* normalization_factor * (a - b * X[2] * normalization_factor)]
#         else:
#             return [X[0]* normalization_factor * (a - b * X[1] * normalization_factor)]
        if include_time:
            return [-X[2]* normalization_factor * (c - d * X[1] * normalization_factor)]
        else:
            return [-X[1]* normalization_factor * (c - d * X[0] * normalization_factor)]

exact = ExactModel()

# %%
from interpolation.interpolate_system import odeint_interpolate
from interpolation.regression_dataset import RegressionDataset

import matplotlib.pyplot as plt
import numpy as np


# number_of_systems = 7
# samples_per_system = 142857
number_of_systems = 1
samples_per_system = 14

dataset_train = None
dataset_test = None

population_size = 50

print("Generating training data...")
# f, axes = plt.subplots(2, 1, sharex='col', sharey='col', figsize=(7, 15))
# f, axes = plt.subplots(1, 2)
f, axes = plt.subplots(1, 1)

for init_conditions in initial_conditions_lotka(population_size, number_of_systems):
#     print(init_conditions)
    y_inter = odeint_interpolate( system, init_conditions, INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d))
    y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]
    
    t = np.linspace(INTERVAL_LOW, INTERVAL_HIGH, 10000)
    X,Y = y_inter
#     Print para tesis
#     x0= 50
#     def find_roots(x,y):
#         s = np.abs(np.diff(np.sign(y))).astype(bool)
#         return x[:-1][s] + np.diff(x)[s]/(np.abs(y[1:][s]/y[:-1][s])+1)
#     axes[0].axvline(x=x0, linestyle=':', color='red')
#     axes[1].axvline(x=x0, linestyle=':', color='red')
#     z = find_roots(np.array([X(ti) for ti in t]), t-x0)
#     axes[0].plot(np.ones_like(z)*x0, z, marker="o", ls="", ms=4, color="limegreen")
#     z = find_roots(np.array([Y(ti) for ti in t]), t-x0)
#     axes[1].plot(np.ones_like(z)*x0, z, marker="o", ls="", ms=4, color="limegreen")
    

#     End print para tesis
#     axes[0].plot(t, [X(ti) for ti in t])
#     axes[1].plot(t, [Y(ti) for ti in t])
    axes.plot(t, [X(ti) for ti in t], label = "x(t)")
    axes.plot(t, [Y(ti) for ti in t], label = "y(t)")
    
    print(init_conditions)
    
    def y_prime(t):
#         return y_inter_time_norm[0](t) * (a - b * y_inter_time_norm[1](t))
        return -y_inter_time_norm[1](t) * (c - d * y_inter_time_norm[0](t))
    
    d_train = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 80 // 100, include_time, 1/4,1/2)
    d_test = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 20 // 100, include_time,1/4, 1/2)
   
    if dataset_train:
        dataset_train.concat_dataset(d_train)
        dataset_test.concat_dataset(d_test)
    else:
        dataset_train = d_train
        dataset_test = d_test




print("Done")
# axes[0].grid()
# axes[1].grid()
# axes[0].set_title("Muestras x(t), y(t)")
# axes[1].set_title("y(t)")
# axes[0].grid()
axes.legend()
plt.savefig('lotka_volterra_example_two_initial_conditions.png')
plt.show()
# Out:
# Generating training data...
# [25, 25]
# Done

# %%
len(dataset_train.X)
print(dataset_train.X[:-5] *100)
# Out:
# tensor([[0.0000e+00, 2.5000e+01, 2.5000e+01],
#         [1.2502e-02, 2.5009e+01, 2.4969e+01],
#         [2.5003e-02, 2.5017e+01, 2.4938e+01],
#         ...,
#         [9.9912e+01, 2.2413e+01, 8.7276e+00],
#         [9.9925e+01, 2.2423e+01, 8.7156e+00],
#         [9.9937e+01, 2.2433e+01, 8.7036e+00]], device='cuda:0',
#        dtype=torch.float64)

# %%
# %load_ext autoreload
# %autoreload 2
from interpolation.regression_nn import RegressionNN
m1 = RegressionNN.nn_dataset_regression(dataset_train, dataset_test)
# Out:
# NVIDIA GeForce RTX 3050 Ti Laptop GPU
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.1 GB
# epoch: 0
# Avg loss: 0.027254622207476004
# epoch: 10
# Avg loss: 0.0019548397475841577
# epoch: 20
# Avg loss: 0.0012899785940052697
# epoch: 30
# Avg loss: 0.04548683833980524
# epoch: 40
# Avg loss: 0.007476952487416674
# epoch: 50
# Avg loss: 0.0020288474656840684
# epoch: 60
# Avg loss: 0.03129773360650794
# epoch: 70
# Avg loss: 0.001255299607939721
# epoch: 80
# Avg loss: 0.002580790385466587
# epoch: 90
# Avg loss: 0.0007958135442378462

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon
import matplotlib.pyplot as plt

y_inter = odeint_interpolate( system, [20, 20], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]

f, axes = plt.subplots(5, 6, figsize=(30, 20))

for i in range(5):
    for j in range(6):
        dependency_graph_epsilon(
            m1,
            1,
            y_inter_time_norm,
            0.25,
            0.5,
            normalization_factor,
            25,
            1000,
            include_time,
            "",
            "b",
            "",
            "",
            exact,
            axes[i,j]
        )

f.supxlabel('X')
f.supylabel('N(X)')
f.suptitle("N(X) for t and Y fixed.  Color red is the exact ideal model", fontsize=14)
plt.savefig('lotka_volterra.pdf', bbox_inches='tight')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.4160244474074557 [array(92.01376131), array(11.73762568)]
# 0.4029437886783094 [array(87.9290691), array(9.52274078)]
# 0.4152925907597124 [array(91.78396471), array(11.59453619)]
# 0.4408635444627167 [array(99.77736268), array(18.52174027)]
# 0.2951749499754708 [array(58.85347499), array(3.59454942)]
# 0.424252788901779 [array(94.60071346), array(13.53579283)]
# 0.49248944159276486 [array(112.21268748), array(59.84185591)]
# 0.490035261262887 [array(111.9109064), array(56.30464886)]
# 0.37440038872858805 [array(79.32501134), array(6.48992934)]
# 0.4388506960537689 [array(99.15827393), array(17.79854088)]
# 0.3482424848497312 [array(71.97513013), array(4.96474983)]
# 0.2560634242430123 [array(50.66889128), array(3.34174772)]
# 0.28569324347650077 [array(56.75831167), array(3.48977219)]
# 0.4479436078762709 [array(101.92250135), array(21.3909271)]
# 0.3679404371499878 [array(77.45786058), array(6.03089717)]
# 0.44366309622639805 [array(100.63225742), array(19.59288115)]
# 0.3951713982386381 [array(85.5358831), array(8.49511404)]
# 0.3975750744053207 [array(86.27259022), array(8.79349097)]
# 0.4596858583359937 [array(105.3110233), array(27.51969022)]
# 0.43784966783910295 [array(98.8491882), array(17.45270777)]
# 0.352872252588818 [array(73.23447413), array(5.17698113)]
# 0.30011398339070133 [array(59.97400357), array(3.66201393)]
# 0.4060859979807814 [array(88.90484313), array(9.99383007)]
# 0.2895723446340263 [array(57.60664594), array(3.52887639)]
# 0.4044831107148772 [array(88.40655818), array(9.74918482)]
# 0.48980608213384635 [array(111.8803196), array(55.98607671)]
# 0.39950595221404483 [array(86.86667054), array(9.04539921)]
# 0.4991971521185865 [array(112.77309514), array(70.77250505)]
# 0.47763061086650505 [array(109.74901788), array(41.61863029)]
# 0.4705937548398228 [array(108.15183545), array(35.25353975)]

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon

f, axes = plt.subplots(1, 1)

dependency_graph_epsilon(
            m1,
            1,
            y_inter_time_norm,
            0.25,
            0.5,
            normalization_factor,
            25,
            1000,
            include_time,
            "",
            "b",
            "",
            "",
            exact,
            axes
        )
f.supxlabel('x')
f.supylabel('h(X)')
f.suptitle("N(t,x,y) para t,y fijos. La recta roja es el modelo ideal exacto", fontsize=14)
plt.savefig('lotka_volterra_example.png')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.30348927290323957 [0.30348927290323957, array(60.75139506), array(3.71360473)]

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_linear_dependency

avg_slope, avg_intercept, avg_r_value_sq = check_linear_dependency(
        m1,
        1,
        y_inter_time_norm,
        0.25,
        0.5,
        normalization_factor,
        25,
        1000,
        include_time)

print(f'avergae intercept: {avg_intercept}')
print(f'avergae r value square: {avg_r_value_sq}')
print(f'avg_slope: {avg_slope}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# avergae intercept: -0.11016759735268211
# avergae r value square: 0.9555531971074799
# avg_slope: 0.1199423551617481

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_polynomial_dependency

result = check_polynomial_dependency(
        m1,
        1,
        y_inter_time_norm,
        0.25,
        0.5,
        3,
        normalization_factor,
        25,
        1000,
        include_time)

print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'polynomial': [4.6191826831097676e-06, -0.0010531624967457323, 0.1239070196066706, -1.4604834098440278], 'determination': 0.9995211056921709}

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad

y_inter = odeint_interpolate( system, [20, 20], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]

values = check_var_exist_grad(m1, 0, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)

values = check_var_exist_grad(m1, 1, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)

values = check_var_exist_grad(m1, 2, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1.0730702694980616
# 7.504092198800611
# 13.176328312685605

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad_dataset

values = check_var_exist_grad_dataset(m1, 0, dataset_train)
avr = sum(values)/len(values)
print(avr)


values = check_var_exist_grad_dataset(m1, 1, dataset_train)
avr = sum(values)/len(values)
print(avr)


# values = check_var_exist_grad_dataset(m1, 2, dataset_train)
# avr = sum(values)/len(values)
# print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 15.047298404143401
# 13.158649382155373
