# %%
import sys
sys.path.append("../")

# %%
import random

INTERVAL_LOW = 0
INTERVAL_HIGH = 100
SAMPLES = int(1e5)

a = 0.04
b = 0.0005
c = 0.2
d = 0.004
normalization_factor = 100

def system(y, t,a,b,c,d):
    X, Y = y   
    dXdt =  X*(a - b*Y) 
    dYdt = -Y*(c - d*X)
    return dXdt, dYdt

def get_time_norm_function(function, max_time):
    def function_norm_time(t):
        return function(t * max_time)

    return function_norm_time


def initial_conditions_lotka(population_size, number_of_initial_conditions):
    def generate_initial_conditions(population_size):
        N = population_size
        x = random.randint(1,N -1)
        y = N - x
        return  [x,y]
    
    yield [population_size//2,population_size//2]
    for i in range(number_of_initial_conditions -1):  
        yield generate_initial_conditions(population_size)

include_time = True
# The ideal trained neural network model
class ExactModel:
    def eval_model(self, X):
        if include_time:
            return [X[1]* normalization_factor * (a - b * X[2] * normalization_factor)]
        else:
            return [X[0]* normalization_factor * (a - b * X[1] * normalization_factor)]
#         if include_time:
#             return [-X[2]* normalization_factor * (c - d * X[1] * normalization_factor)]
#         else:
#             return [-X[1]* normalization_factor * (c - d * X[0] * normalization_factor)]

exact = ExactModel()

# %%
from interpolation.interpolate_system import odeint_interpolate
from interpolation.regression_dataset import RegressionDataset

import matplotlib.pyplot as plt
import numpy as np


number_of_systems = 7
samples_per_system = 1428
# number_of_systems = 1
# samples_per_system = 14

dataset_train = None
dataset_test = None

population_size = 50

print("Generating training data...")
# f, axes = plt.subplots(2, 1, sharex='col', sharey='col', figsize=(7, 15))
f, axes = plt.subplots(1, 2)
# f, axes = plt.subplots(1, 1)

for init_conditions in initial_conditions_lotka(population_size, number_of_systems):
#     print(init_conditions)
    y_inter = odeint_interpolate( system, init_conditions, INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d))
    y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]
    
    t = np.linspace(INTERVAL_LOW, INTERVAL_HIGH, 10000)
    X,Y = y_inter
#     Print para tesis
#     x0= 50
#     def find_roots(x,y):
#         s = np.abs(np.diff(np.sign(y))).astype(bool)
#         return x[:-1][s] + np.diff(x)[s]/(np.abs(y[1:][s]/y[:-1][s])+1)
#     axes[0].axvline(x=x0, linestyle=':', color='red')
#     axes[1].axvline(x=x0, linestyle=':', color='red')
#     z = find_roots(np.array([X(ti) for ti in t]), t-x0)
#     axes[0].plot(np.ones_like(z)*x0, z, marker="o", ls="", ms=4, color="limegreen")
#     z = find_roots(np.array([Y(ti) for ti in t]), t-x0)
#     axes[1].plot(np.ones_like(z)*x0, z, marker="o", ls="", ms=4, color="limegreen")
    

#     End print para tesis
    axes[0].plot(t, [X(ti) for ti in t])
    axes[1].plot(t, [Y(ti) for ti in t])
#     axes.plot(t, [X(ti) for ti in t], label = "x(t)")
#     axes.plot(t, [Y(ti) for ti in t], label = "y(t)")
    
    print(init_conditions)
    
    def y_prime(t):
        return y_inter_time_norm[0](t) * (a - b * y_inter_time_norm[1](t))
#         return -y_inter_time_norm[1](t) * (c - d * y_inter_time_norm[0](t))
    
    d_train = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 80 // 100, include_time, 0,1)
    d_test = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 20 // 100, include_time,0, 1)
   
    if dataset_train:
        dataset_train.concat_dataset(d_train)
        dataset_test.concat_dataset(d_test)
    else:
        dataset_train = d_train
        dataset_test = d_test




print("Done")
axes[0].grid()
axes[1].grid()
axes[0].set_title("x(t)")
axes[1].set_title("y(t)")
# axes[0].grid()
# axes.legend()
# plt.savefig('lotka_volterra_example_two_initial_conditions.png')
plt.show()
# Out:
# Generating training data...
# [25, 25]
# [21, 29]
# [15, 35]
# [25, 25]
# [25, 25]
# [42, 8]
# [18, 32]
# Done

# %%
len(dataset_train.X)
print(dataset_train.X[:-5] *100)
# Out:
# tensor([[25.0000, 25.0000],
#         [25.0604, 24.7821],
#         [25.1213, 24.5666],
#         ...,
#         [27.2219,  7.4878],
#         [27.3085,  7.4284],
#         [27.3956,  7.3696]], device='cuda:0', dtype=torch.float64)

# %%
# %load_ext autoreload
# %autoreload 2
from interpolation.regression_nn import RegressionNN
m1 = RegressionNN.nn_dataset_regression(dataset_train, dataset_test)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# NVIDIA GeForce RTX 3050 Ti Laptop GPU
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.1 GB
# epoch: 0
# train_loss: 6.945909370944376
# test_loss: 6.674731802423122
# epoch: 10
# train_loss: 0.6270661230080232
# test_loss: 0.334468033960003
# epoch: 20
# train_loss: 0.015427731357031144
# test_loss: 0.02072950557123779
# epoch: 30
# train_loss: 0.023437481962052302
# test_loss: 0.025624199933757967
# epoch: 40
# train_loss: 0.006225073403182421
# test_loss: 0.008512981167629812
# epoch: 50
# train_loss: 0.02123933428091006
# test_loss: 0.005603824012080786
# epoch: 60
# train_loss: 0.00742544532691272
# test_loss: 0.014140754347070175
# epoch: 70
# train_loss: 0.004106837812977231
# test_loss: 0.003834150589228141
# epoch: 80
# train_loss: 0.0030209582743670185
# test_loss: 0.005320493995449701
# epoch: 90
# train_loss: 0.0033121706183103722
# test_loss: 0.00867273720513945
# train_loss: 0.0031482452792249713
# test_loss: 0.003982753482046811

# %%
m1.plot_learn_history()

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon
import matplotlib.pyplot as plt

y_inter = odeint_interpolate( system, [20, 20], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]

f, axes = plt.subplots(5, 6, figsize=(30, 20))

for i in range(5):
    for j in range(6):
        dependency_graph_epsilon(
            m1,
            0,
            y_inter_time_norm,
            0.25,
            0.5,
            normalization_factor,
            25,
            1000,
            include_time,
            "",
            "b",
            "",
            "",
            exact,
            axes[i,j]
        )

f.supxlabel('X')
f.supylabel('N(X)')
f.suptitle("N(X) for t and Y fixed.  Color red is the exact ideal model", fontsize=14)
plt.savefig('lotka_volterra.pdf', bbox_inches='tight')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.3295261911059377 [array(67.07189934), array(4.29043558)]
# 0.33506345793691955 [array(68.49104385), array(4.46276124)]
# 0.28464838069449816 [array(56.5318795), array(3.48009364)]
# 0.36748218654664044 [array(77.32666788), array(6.00069189)]
# 0.47745986424914555 [array(109.7129824), array(41.44919098)]
# 0.38697325842120844 [array(83.04932811), array(7.59164621)]
# 0.3214174935418621 [array(65.04142884), array(4.07277306)]
# 0.46843691706092216 [array(107.6211366), array(33.53615099)]
# 0.27600562247913774 [array(54.69226514), array(3.41328357)]
# 0.29899273712281615 [array(59.71785509), array(3.64587869)]
# 0.4685102801027435 [array(107.63946953), array(33.59291442)]
# 0.30617100774361156 [array(61.37582952), array(3.75793786)]
# 0.4044279027117769 [array(88.389415), array(9.7409215)]
# 0.4439332818762677 [array(100.71433947), array(19.70047552)]
# 0.4712063834427098 [array(108.29933723), array(35.76015327)]
# 0.38954328568612917 [array(83.8242566), array(7.85713064)]
# 0.3469163748928529 [array(71.61778908), array(4.90767926)]
# 0.40017643184461504 [array(87.07341335), array(9.13553098)]
# 0.46963858013271365 [array(107.91895703), array(34.48044165)]
# 0.2624652835749619 [array(51.9274949), array(3.35285336)]
# 0.28031813781682985 [array(55.60277911), array(3.44371956)]
# 0.46300656237689986 [array(106.21429126), array(29.63551638)]
# 0.4126358685133576 [array(90.95068316), array(11.095876)]
# 0.32603593333412084 [array(66.1909782), array(4.19196787)]
# 0.49146817696554584 [array(112.09292864), array(58.34159332)]
# 0.40719051881653345 [array(89.24880206), array(10.16786604)]
# 0.40096972096497163 [array(87.31831639), array(9.24399486)]
# 0.40156355226927487 [array(87.50184554), array(9.32650405)]
# 0.39233272512556594 [array(84.67015799), array(8.16317537)]
# 0.31795670523171565 [array(64.19201851), array(3.99119678)]

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon

f, axes = plt.subplots(1, 1)

dependency_graph_epsilon(
            m1,
            0,
            y_inter_time_norm,
            0.25,
            0.5,
            normalization_factor,
            25,
            1000,
            include_time,
            "",
            "b",
            "",
            "",
            exact,
            axes
        )
f.supxlabel('x')
f.supylabel('h(X)')
f.suptitle("N(t,x,y) para t,y fijos. La recta roja es el modelo ideal exacto", fontsize=14)
plt.savefig('lotka_volterra_example.png')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.3060366338103295 [array(61.3443975), array(3.75564396)]

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_linear_dependency

avg_slope, avg_intercept, avg_r_value_sq = check_linear_dependency(
        m1,
        1,
        y_inter_time_norm,
        0.25,
        0.5,
        normalization_factor,
        25,
        1000,
        include_time)

print(f'avergae intercept: {avg_intercept}')
print(f'avergae r value square: {avg_r_value_sq}')
print(f'avg_slope: {avg_slope}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# avergae intercept: -0.11016759735268211
# avergae r value square: 0.9555531971074799
# avg_slope: 0.1199423551617481

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_polynomial_dependency

result = check_polynomial_dependency(
        m1,
        1,
        y_inter_time_norm,
        0.25,
        0.5,
        3,
        normalization_factor,
        25,
        1000,
        include_time)

print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'polynomial': [4.6191826831097676e-06, -0.0010531624967457323, 0.1239070196066706, -1.4604834098440278], 'determination': 0.9995211056921709}

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad

y_inter = odeint_interpolate( system, [20, 20], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]

values = check_var_exist_grad(m1, 0, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)

values = check_var_exist_grad(m1, 1, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)

values = check_var_exist_grad(m1, 2, y_inter_time_norm, 0, 1)
avr = sum(values)/len(values)
print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1.0730702694980616
# 7.504092198800611
# 13.176328312685605

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad_dataset

values = check_var_exist_grad_dataset(m1, 0, dataset_train)
avr = sum(values)/len(values)
print(avr)


values = check_var_exist_grad_dataset(m1, 1, dataset_train)
avr = sum(values)/len(values)
print(avr)


# values = check_var_exist_grad_dataset(m1, 2, dataset_train)
# avr = sum(values)/len(values)
# print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 15.047298404143401
# 13.158649382155373
