# %%
import sys
sys.path.append("../")

# %%
import random

INTERVAL_LOW = 0
INTERVAL_HIGH = 100
SAMPLES = int(1e5)

a = -0.1
b = 2
c = -2
d = -0.1
normalization_factor = 2

def system(y, t,a,b,c,d):
    x, y = y   
    dXdt = a* x**3 + b* y **3
    dYdt = c * x**3 + d* y **3
    return dXdt, dYdt

def get_time_norm_function(function, max_time):
    def function_norm_time(t):
        return function(t * max_time)

    return function_norm_time


def initial_conditions(number_of_initial_conditions):
    def generate_initial_conditions():
        x = random.uniform(-2,2)
        y = random.uniform(-2,2)
        return  [x,y]
    
    yield [0.5,-0.5]
    for i in range(number_of_initial_conditions -1):  
        yield generate_initial_conditions()

include_time = True
# The ideal trained neural network model
class ExactModel:
    def eval_model(self, X):
        if include_time:
            return [a * (X[1]* normalization_factor ) ** 3 + b * (X[2]* normalization_factor  )**3]
        else:
            return [a * (X[0]* normalization_factor ) ** 3 + b * (X[1]* normalization_factor  )**3]


exact = ExactModel()

# %%
from interpolation.interpolate_system import odeint_interpolate
from interpolation.regression_dataset import RegressionDataset

import matplotlib.pyplot as plt
import numpy as np


number_of_systems = 16
# samples_per_system = 10
samples_per_system = 625

dataset_train = None
dataset_test = None


print("Generating training data...")
# f, axes = plt.subplots(2, 1, sharex='col', sharey='col', figsize=(7, 15))
f, axes = plt.subplots(1, 2)

for init_conditions in initial_conditions(number_of_systems):
    print(init_conditions)
    y_inter = odeint_interpolate( system, init_conditions, INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d))
    y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]
    
    t = np.linspace(INTERVAL_LOW, INTERVAL_HIGH, 10000)
    X,Y = y_inter

    axes[0].plot(t, [X(ti) for ti in t])
    axes[1].plot(t, [Y(ti) for ti in t])
    
    
#     print(init_conditions)

    def y_prime(t):
        return a* y_inter_time_norm[0](t)**3 + b*y_inter_time_norm[1](t) **3
    
    d_train = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 80 // 100, include_time, 0, 1/4)
    d_test = RegressionDataset(y_inter_time_norm, y_prime, normalization_factor, samples_per_system * 20 // 100, include_time, 0, 1/4)
   
    if dataset_train:
        dataset_train.concat_dataset(d_train)
        dataset_test.concat_dataset(d_test)
    else:
        dataset_train = d_train
        dataset_test = d_test




print("Done")
axes[0].grid()
axes[1].grid()
axes[0].set_title("x(t)")
axes[1].set_title("y(t)")

# plt.savefig('lotka_volterra_example_two_initial_conditions.png')
plt.show()
# Out:
# Generating training data...
# [0.5, -0.5]
# [1.7295166806361149, 0.9007941068913201]
# [-1.9702680457652821, 0.5052746053025001]
# [1.059229888617212, 1.9020026365343217]
# [0.9378035264974134, -1.2695014120273371]
# [0.23021305665860003, 1.9245872678955838]
# [0.7660797053225985, 0.10315181408450602]
# [-0.4965357808765356, 1.0611109913555805]
# [-1.7873807575896983, 1.313595089906539]
# [-1.738386094613075, -1.701743259908965]
# [1.884782753943398, -0.1719849425690123]
# train_loss: 0.00799885067021358
# test_loss: 0.008701236913310194
# epoch: 310
# train_loss: 0.007776878889032317
# test_loss: 0.008565480686982156
# epoch: 320
# train_loss: 0.007537153613275299
# test_loss: 0.008292325410428578
# epoch: 330
# train_loss: 0.007391755458283618
# test_loss: 0.008240378511018168
# epoch: 340
# train_loss: 0.007191453474012825
# test_loss: 0.007869873755227588
# epoch: 350
# train_loss: 0.007059088788239656
# test_loss: 0.007795221439989548
# epoch: 360
# train_loss: 0.0068132263510382466
# test_loss: 0.007434275606315149
# epoch: 370
# train_loss: 0.006593831690347756
# test_loss: 0.007237556451530392
# epoch: 380
# train_loss: 0.006359850350156262
# test_loss: 0.007082515370056537
# epoch: 390
# train_loss: 0.006193703324580274
# test_loss: 0.006819573840408941
# epoch: 400
# train_loss: 0.0059638880269471785
# test_loss: 0.006610560598128147
# epoch: 410
# train_loss: 0.005874237244240839
# test_loss: 0.006367123105241504
# epoch: 420
# train_loss: 0.0055840271631975155
# test_loss: 0.006143156287804466
# epoch: 430
# train_loss: 0.0054353361128383374
# test_loss: 0.005992943413716402
# epoch: 440
# train_loss: 0.005319425435921049
# test_loss: 0.005832099733253396
# epoch: 450
# train_loss: 0.0051651433663620966
# test_loss: 0.0056761030384983036
# epoch: 460
# train_loss: 0.005009139604655025
# test_loss: 0.005538201386371711
# epoch: 470
# train_loss: 0.004946787996765414
# test_loss: 0.005487690879423145
# epoch: 480
# train_loss: 0.004835041180796418
# test_loss: 0.0053122110657458236
# epoch: 490
# train_loss: 0.00473410983567539
# test_loss: 0.005221500146894591
# train_loss: 0.004597680687391236
# test_loss: 0.005046795649150697

# %%
m1.plot_learn_history(200,500)

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.graph_dependency import dependency_graph_epsilon
import matplotlib.pyplot as plt

y_inter = odeint_interpolate( system, [0.5, -0.5], INTERVAL_LOW, INTERVAL_HIGH, 10000, (a,b,c,d) )
y_inter_time_norm = [get_time_norm_function(yi, INTERVAL_HIGH) for yi in y_inter]

f, axes = plt.subplots(5, 6, figsize=(30, 20))

for i in range(5):
    for j in range(6):
        dependency_graph_epsilon(
            m1,
            1,
            y_inter_time_norm,
            0,
            1/4,
            normalization_factor,
            0.05,
            1000,
            include_time,
            "",
            "b",
            "",
            "",
            exact,
            axes[i,j]
        )

f.supxlabel('X')
f.supylabel('N(X)')
f.suptitle("N(X) for t and Y fixed.  Color red is the exact ideal model", fontsize=14)
plt.savefig('lotka_volterra.pdf', bbox_inches='tight')
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.02065489794034142 [0.02065489794034142, array(-0.24435413), array(-0.55269348)]
# 0.14817148321760165 [0.14817148321760165, array(0.36719573), array(-0.34961482)]
# 0.08263294403418589 [0.08263294403418589, array(0.02527316), array(0.48130899)]
# 0.12437884499467033 [0.12437884499467033, array(0.44438364), array(0.00774645)]
# 0.20712662211431565 [0.20712662211431565, array(-0.3446413), array(-0.31021334)]
# 0.22062621349443923 [0.22062621349443923, array(-0.38044624), array(-0.17286097)]
# 0.10934448415382103 [0.10934448415382103, array(0.44114633), array(0.2784329)]
# 0.04300585601995663 [0.04300585601995663, array(-0.5271498), array(-0.05321868)]
# 0.06973823110546976 [0.06973823110546976, array(-0.2723916), array(0.48434767)]
# 0.07240049439150212 [0.07240049439150212, array(-0.21046729), array(0.48889786)]
# 0.034601127070057636 [0.034601127070057636, array(-0.52534396), array(-0.30413378)]
# 0.1215086908555715 [0.1215086908555715, array(0.44689081), array(0.0585522)]
# 0.07202912117230462 [0.07202912117230462, array(-0.21917596), array(0.4885948)]
# 0.13385094844695997 [0.13385094844695997, array(0.43464778), array(-0.1535459)]
# 0.2112537316763882 [0.2112537316763882, array(-0.36337653), array(-0.27232419)]
# 0.2359430877651586 [0.2359430877651586, array(-0.37611168), array(-0.00529513)]
# 0.02574152276988717 [0.02574152276988717, array(-0.39805943), array(-0.50816458)]
# 0.04732938219070165 [0.04732938219070165, array(-0.52089641), array(0.07121578)]
# 0.1968132007201453 [0.1968132007201453, array(-0.26100454), array(-0.37536738)]
# 0.20780467601038885 [0.20780467601038885, array(-0.34829525), array(-0.30437536)]
# 0.12701770220799602 [0.12701770220799602, array(0.44207971), array(-0.03820884)]
# 0.060109439704639306 [0.060109439704639306, array(-0.45389042), array(0.38837341)]
# 0.026057061259161934 [0.026057061259161934, array(-0.40602689), array(-0.50365385)]
# 0.23815058952995546 [0.23815058952995546, array(-0.37494216), array(0.01808529)]
# 0.13072329495469268 [0.13072329495469268, array(0.43860864), array(-0.10149729)]
# 0.19493867324258393 [0.19493867324258393, array(-0.24089614), array(-0.3823292)]
# 0.1992635937657033 [0.1992635937657033, array(-0.28532155), array(-0.36409544)]
# 0.004986809583290147 [0.004986809583290147, array(0.33601758), array(-0.5701822)]
# 0.19022459784012338 [0.19022459784012338, array(-0.18586385), array(-0.39447635)]
# 0.1550766191468346 [0.1550766191468346, array(0.29084236), array(-0.3967498)]

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.check_var_exist import check_var_exist_grad_dataset

values = check_var_exist_grad_dataset(m1, 0, dataset_train)
avr = sum(values)/len(values)
print(avr)


values = check_var_exist_grad_dataset(m1, 1, dataset_train)
avr = sum(values)/len(values)
print(avr)


values = check_var_exist_grad_dataset(m1, 2, dataset_train)
avr = sum(values)/len(values)
print(avr)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.09010347602296662
# 0.15200575661308796
# 4.42052314744823

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_polynomial_dependency

result = check_polynomial_dependency(
        m1,
#         exact,
        1,
        y_inter_time_norm,
        0,
        1/4,
        3,
        normalization_factor,
        0.5,
        1000,
        include_time)

print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'polynomial': [0.0016023248186383106, 0.00639416681604325, -0.045354161464720294, -0.1359132561839518], 'determination': 0.9999999999996683}

# %%
# %load_ext autoreload
# %autoreload 2
from query_set.regression_dependency import check_polynomial_dependency

result = check_polynomial_dependency(
        m1,
        2,
        y_inter_time_norm,
        0.4,
        0.8,
        3,
        normalization_factor,
        0.5,
        1000,
        include_time)

print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'polynomial': [0.0030910028691989466, -0.03074128559033551, 0.8931948426618556, 0.0360381042811483], 'determination': 0.9999999999972257}
